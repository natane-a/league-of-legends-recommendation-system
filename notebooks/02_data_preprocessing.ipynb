# %%
import json
import pandas as pd

with open("../data/raw/match_details/all_match_details01.json", "r") as f:
    match_data = json.load(f)

# Convert the list of matches to a DataFrame
df = pd.DataFrame(match_data)

df.head()
# Out:
#           matchId  gameDuration  championId championName  teamId  \
# 0  NA1_5159373690          2405          24          Jax     100
# 1  NA1_5159373690          2405          30      Karthus     100
# 2  NA1_5159373690          2405          91        Talon     100
# 3  NA1_5159373690          2405          22         Ashe     100
# 4  NA1_5159373690          2405         432         Bard     100
#
#   individualPosition  kills  deaths  assists   win  ...  item_1  \
# 0                TOP      7       6       10  True  ...    6610
# 1             JUNGLE     16      13       12  True  ...    2503
# 2             MIDDLE     22      14       16  True  ...    6698
# 3             BOTTOM      2      10       11  True  ...    6672
# 4            UTILITY      4       6       27  True  ...    3084
#
#    item_purchase_time_1  item_2  item_purchase_time_2 item_3  \
# 0                  1149    2504                  1901   3078
# 1                   545    3020                  1930   3118
# ...

# %%
df['championName'].value_counts()
# Out:
# championName
# Caitlyn         213
# Graves          178
# Jhin            172
# Viego           158
# Jinx            158
#                ...
# Trundle          16
# Heimerdinger     15
# Rammus           14
# Annie            12
# Quinn             9
# Name: count, Length: 169, dtype: int64
